# %% [markdown]
# # FIRST EDA OF CLIMATE CHANGE DATA

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/davidcraig/code/antoninolm/climate_change_project/raw_data

# %%
import pandas as pd

# %%
# 1. Load Data
# Load the dataset, treating the first row as headers
df = pd.read_csv("../raw_data/Q_13_previous-1950-2023_RR-T-Vent.csv.gz", compression="gzip", delimiter=";")

# Save the transformed dataset
# df.to_csv("Q_13_previous-1950-2023_RR-T-Vent.csv", index=False)

print("Data successfully extracted and saved with headers!")
print(df.head(20))  # Display first few rows
# Out:
# Data successfully extracted and saved with headers!
#     NUM_POSTE      NOM_USUEL        LAT       LON  ALTI  AAAAMMJJ   RR  QRR  \
# 0    13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620701  0.0  1.0
# 1    13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620702  0.0  1.0
# 2    13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620703  0.0  1.0
# 3    13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620704  0.0  1.0
# 4    13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620705  0.0  1.0
# 5    13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620706  0.0  1.0
# 6    13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620707  0.0  1.0
# 7    13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620708  0.0  1.0
# 8    13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620709  0.0  1.0
# 9    13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620710  0.0  1.0
# 10   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620711  0.0  1.0
# 11   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620712  0.0  1.0
# 12   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620713  0.0  1.0
# 13   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620714  0.0  1.0
# 14   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620715  0.0  1.0
# 15   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620716  0.0  1.0
# 16   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620717  0.0  1.0
# 17   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620718  0.0  1.0
# 18   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620719  0.0  1.0
# 19   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620720  0.0  1.0
#
#     TN  QTN  ...  HXI2  QHXI2  FXI3S  QFXI3S  DXI3S  QDXI3S  HXI3S  QHXI3S  \
# 0  NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 1  NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2  NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 3  NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 4  NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 5  NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 6  NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 7  NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 8  NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 9  NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 10 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 11 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 12 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 13 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 14 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 15 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 16 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 17 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 18 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 19 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
#
#     DRR  QDRR
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   NaN   NaN
# 4   NaN   NaN
# 5   NaN   NaN
# 6   NaN   NaN
# 7   NaN   NaN
# 8   NaN   NaN
# 9   NaN   NaN
# 10  NaN   NaN
# 11  NaN   NaN
# 12  NaN   NaN
# 13  NaN   NaN
# 14  NaN   NaN
# 15  NaN   NaN
# 16  NaN   NaN
# 17  NaN   NaN
# 18  NaN   NaN
# 19  NaN   NaN
#
# [20 rows x 58 columns]

# %%
df.shape
# Out:
# (1202310, 58)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['NUM_POSTE;NOM_USUEL;LAT;LON;ALTI;AAAAMMJJ;RR;QRR;TN;QTN;HTN;QHTN;TX;QTX;HTX;QHTX;TM;QTM;TNTXM;QTNTXM;TAMPLI;QTAMPLI;TNSOL;QTNSOL;TN50;QTN50;DG;QDG;FFM;QFFM;FF2M;QFF2M;FXY;QFXY;DXY;QDXY;HXY;QHXY;FXI;QFXI;DXI;QDXI;HXI;QHXI;FXI2;QFXI2;DXI2;QDXI2;HXI2;QHXI2;FXI3S;QFXI3S;DXI3S;QDXI3S;HXI3S;QHXI3S;DRR;QDRR'], dtype='object')

# %%
# 2. Overview of the Data
print("\nBasic Info:")
df.info()
print("\nFirst 10 Rows:")
print(df.head(10))
print("\nMissing Values:")
display(df.isnull().sum())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1202310 entries, 0 to 1202309
# Data columns (total 58 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   NUM_POSTE  1202310 non-null  int64
#  1   NOM_USUEL  1202310 non-null  object
#  2   LAT        1202310 non-null  float64
#  3   LON        1202310 non-null  float64
#  4   ALTI       1202310 non-null  int64
#  5   AAAAMMJJ   1202310 non-null  int64
#  6   RR         1175688 non-null  float64
#  7   QRR        1175972 non-null  float64
#  8   TN         648449 non-null   float64
#  9   QTN        648549 non-null   float64
#  10  HTN        286614 non-null   float64
#  11  QHTN       286810 non-null   float64
#  12  TX         637884 non-null   float64
#  13  QTX        638354 non-null   float64
#  14  HTX        286703 non-null   float64
#  15  QHTX       287277 non-null   float64
#  16  TM         339774 non-null   float64
#  17  QTM        339792 non-null   float64
#  18  TNTXM      637799 non-null   float64
#  19  QTNTXM     637808 non-null   float64
#  20  TAMPLI     637799 non-null   float64
#  21  QTAMPLI    637808 non-null   float64
#  22  TNSOL      145165 non-null   float64
#  23  QTNSOL     145249 non-null   float64
#  24  TN50       15325 non-null    float64
#  25  QTN50      15327 non-null    float64
#  26  DG         257221 non-null   float64
#  27  QDG        257358 non-null   float64
#  28  FFM        299387 non-null   float64
#  29  QFFM       299578 non-null   float64
#  30  FF2M       0 non-null        float64
#  31  QFF2M      0 non-null        float64
#  32  FXY        224808 non-null   float64
#  33  QFXY       224986 non-null   float64
#  34  DXY        223898 non-null   float64
#  35  QDXY       224079 non-null   float64
#  36  HXY        210893 non-null   float64
#  37  QHXY       211074 non-null   float64
#  38  FXI        295669 non-null   float64
#  39  QFXI       295863 non-null   float64
#  40  DXI        281831 non-null   float64
#  41  QDXI       282026 non-null   float64
#  42  HXI        223558 non-null   float64
#  43  QHXI       223804 non-null   float64
#  44  FXI2       0 non-null        float64
#  45  QFXI2      0 non-null        float64
#  46  DXI2       0 non-null        float64
#  47  QDXI2      0 non-null        float64
#  48  HXI2       0 non-null        float64
#  49  QHXI2      0 non-null        float64
#  50  FXI3S      39214 non-null    float64
#  51  QFXI3S     39677 non-null    float64
#  52  DXI3S      1 non-null        float64
#  53  QDXI3S     466 non-null      float64
#  54  HXI3S      39213 non-null    float64
#  55  QHXI3S     39676 non-null    float64
#  56  DRR        18267 non-null    float64
#  57  QDRR       19117 non-null    float64
# dtypes: float64(54), int64(3), object(1)
# memory usage: 532.0+ MB
#
# First 10 Rows:
#    NUM_POSTE      NOM_USUEL        LAT       LON  ALTI  AAAAMMJJ   RR  QRR  \
# 0   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620701  0.0  1.0
# 1   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620702  0.0  1.0
# 2   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620703  0.0  1.0
# 3   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620704  0.0  1.0
# 4   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620705  0.0  1.0
# 5   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620706  0.0  1.0
# 6   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620707  0.0  1.0
# 7   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620708  0.0  1.0
# 8   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620709  0.0  1.0
# 9   13001002  AIX-PUYRICARD  43.593333  5.413333   314  19620710  0.0  1.0
#
#    TN  QTN  ...  HXI2  QHXI2  FXI3S  QFXI3S  DXI3S  QDXI3S  HXI3S  QHXI3S  \
# 0 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 1 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 3 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 4 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 5 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 6 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 7 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 8 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 9 NaN  NaN  ...   NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
#
#    DRR  QDRR
# 0  NaN   NaN
# 1  NaN   NaN
# 2  NaN   NaN
# 3  NaN   NaN
# 4  NaN   NaN
# 5  NaN   NaN
# 6  NaN   NaN
# 7  NaN   NaN
# 8  NaN   NaN
# 9  NaN   NaN
#
# [10 rows x 58 columns]
#
# Missing Values:
# NUM_POSTE          0
# NOM_USUEL          0
# LAT                0
# LON                0
# ALTI               0
# AAAAMMJJ           0
# RR             26622
# QRR            26338
# TN            553861
# QTN           553761
# HTN           915696
# QHTN          915500
# TX            564426
# QTX           563956
# HTX           915607
# QHTX          915033
# TM            862536
# QTM           862518
# TNTXM         564511
# QTNTXM        564502
# TAMPLI        564511
# QTAMPLI       564502
# TNSOL        1057145
# QTNSOL       1057061
# TN50         1186985
# QTN50        1186983
# DG            945089
# QDG           944952
# FFM           902923
# QFFM          902732
# FF2M         1202310
# QFF2M        1202310
# FXY           977502
# QFXY          977324
# DXY           978412
# QDXY          978231
# HXY           991417
# QHXY          991236
# FXI           906641
# QFXI          906447
# DXI           920479
# QDXI          920284
# HXI           978752
# QHXI          978506
# FXI2         1202310
# QFXI2        1202310
# DXI2         1202310
# QDXI2        1202310
# HXI2         1202310
# QHXI2        1202310
# FXI3S        1163096
# QFXI3S       1162633
# DXI3S        1202309
# QDXI3S       1201844
# HXI3S        1163097
# QHXI3S       1162634
# DRR          1184043
# QDRR         1183193
# dtype: int64

# %%
# 3. Summary Statistics
print("\nSummary Statistics:")
display(df.describe())
# Out:
# Summary Statistics:
#           NUM_POSTE           LAT           LON          ALTI      AAAAMMJJ  \
# count  1.202310e+06  1.202310e+06  1.202310e+06  1.202310e+06  1.202310e+06
# mean   1.305502e+07  4.349369e+01  5.196709e+00  1.101187e+02  1.984885e+07
# std    3.369732e+04  1.861468e-01  3.441533e-01  1.177683e+02  1.889491e+05
# min    1.300100e+07  4.317467e+01  4.423333e+00  1.000000e+00  1.950010e+07
# 25%    1.302800e+07  4.333167e+01  4.927500e+00  1.500000e+01  1.969102e+07
# 50%    1.305500e+07  4.347167e+01  5.216000e+00  6.500000e+01  1.985042e+07
# 75%    1.308600e+07  4.362833e+01  5.499667e+00  1.760000e+02  2.000033e+07
# max    1.311300e+07  4.391667e+01  5.710000e+00  1.025000e+03  2.023123e+07
#
#                  RR           QRR             TN            QTN  \
# count  1.175688e+06  1.175972e+06  648449.000000  648549.000000
# mean   1.646593e+00  1.104946e+00       9.211129       1.011632
# std    6.449003e+00  9.106971e-01       6.467356       0.306827
# min    0.000000e+00  0.000000e+00     -20.200000       0.000000
# 25%    0.000000e+00  1.000000e+00       4.500000       1.000000
# 50%    0.000000e+00  1.000000e+00       9.400000       1.000000
# 75%    0.000000e+00  1.000000e+00      14.300000       1.000000
# max    2.650000e+02  9.000000e+00      29.300000       9.000000
#
#                  HTN  ...  HXI2  QHXI2         FXI3S        QFXI3S  DXI3S  \
# count  286614.000000  ...   0.0    0.0  39214.000000  39677.000000    1.0
# mean      673.499058  ...   NaN    NaN     12.208252      3.741412  140.0
# std       606.333369  ...   NaN    NaN      5.545531      3.797032    NaN
# min         0.000000  ...   NaN    NaN      2.000000      0.000000  140.0
# 25%       345.000000  ...   NaN    NaN      8.200000      1.000000  140.0
# 50%       448.000000  ...   NaN    NaN     10.800000      1.000000  140.0
# 75%       630.000000  ...   NaN    NaN     15.200000      9.000000  140.0
# max      2359.000000  ...   NaN    NaN     44.800000      9.000000  140.0
#
#            QDXI3S         HXI3S        QHXI3S           DRR          QDRR
# count  466.000000  39213.000000  39676.000000  18267.000000  19117.000000
# mean     1.583691   1240.318925      8.814497     52.111732      8.599676
# std      2.082821    596.116936      1.204012    147.263621      1.744949
# min      1.000000      0.000000      1.000000      0.000000      0.000000
# 25%      1.000000    944.000000      9.000000      0.000000      9.000000
# 50%      1.000000   1314.000000      9.000000      0.000000      9.000000
# 75%      1.000000   1550.000000      9.000000      6.000000      9.000000
# max      9.000000   2359.000000      9.000000   1440.000000      9.000000
#
# [8 rows x 57 columns]

# %%
# 4. Check for Duplicates
duplicates = df.duplicated().sum()
print(f"\nNumber of Duplicated Rows: {duplicates}")
# Out:
# Number of Duplicated Rows: 0

# %%
# 5. Visualizing Missing Data
#plt.figure(figsize=(10, 6))
#sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
#plt.title("Missing Values Heatmap")
#plt.show()

# %%
# 6. Distribution of Numeric Features
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
for col in num_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
# 8. Correlation Matrix
#plt.figure(figsize=(10, 6))
#sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
#plt.title("Feature Correlation Matrix")
#plt.show()

# %%
# Count unique values in the Location column after splitting
unique_places = df.iloc[:, 0].nunique()

print(f"Number of unique places in Column 1: {unique_places}")
# Out:
# Number of unique places in Column 1: 120

# %%
# 9.Convert all columns to numeric (if possible)
df_numeric = df.apply(pd.to_numeric, errors="coerce")

# Create a DataFrame with min and max values
min_max_df = pd.DataFrame({"Min": df_numeric.min(), "Max": df_numeric.max()})

# Print the DataFrame
print(min_max_df)
# Out:
#                     Min           Max
# NUM_POSTE  1.300100e+07  1.311300e+07
# NOM_USUEL           NaN           NaN
# LAT        4.317467e+01  4.391667e+01
# LON        4.423333e+00  5.710000e+00
# ALTI       1.000000e+00  1.025000e+03
# AAAAMMJJ   1.950010e+07  2.023123e+07
# RR         0.000000e+00  2.650000e+02
# QRR        0.000000e+00  9.000000e+00
# TN        -2.020000e+01  2.930000e+01
# QTN        0.000000e+00  9.000000e+00
# HTN        0.000000e+00  2.359000e+03
# QHTN       1.000000e+00  9.000000e+00
# TX        -1.160000e+01  4.460000e+01
# QTX        0.000000e+00  9.000000e+00
# HTX        0.000000e+00  2.359000e+03
# QHTX       1.000000e+00  9.000000e+00
# TM        -1.220000e+01  3.300000e+01
# QTM        1.000000e+00  9.000000e+00
# TNTXM     -1.320000e+01  3.450000e+01
# QTNTXM     0.000000e+00  9.000000e+00
# TAMPLI     0.000000e+00  2.900000e+01
# QTAMPLI    0.000000e+00  9.000000e+00
# TNSOL     -1.860000e+01  2.660000e+01
# QTNSOL     0.000000e+00  9.000000e+00
# TN50      -1.200000e+01  2.670000e+01
# QTN50      1.000000e+00  9.000000e+00
# DG         0.000000e+00  1.440000e+03
# QDG        1.000000e+00  9.000000e+00
# FFM        0.000000e+00  3.170000e+01
# QFFM       0.000000e+00  9.000000e+00
# FF2M                NaN           NaN
# QFF2M               NaN           NaN
# FXY        0.000000e+00  3.900000e+01
# QFXY       0.000000e+00  9.000000e+00
# DXY        0.000000e+00  3.600000e+02
# QDXY       0.000000e+00  9.000000e+00
# HXY        0.000000e+00  2.359000e+03
# QHXY       0.000000e+00  9.000000e+00
# FXI        0.000000e+00  5.300000e+01
# QFXI       0.000000e+00  9.000000e+00
# DXI        0.000000e+00  3.600000e+02
# QDXI       0.000000e+00  9.000000e+00
# HXI        0.000000e+00  2.359000e+03
# QHXI       0.000000e+00  9.000000e+00
# FXI2                NaN           NaN
# QFXI2               NaN           NaN
# DXI2                NaN           NaN
# QDXI2               NaN           NaN
# HXI2                NaN           NaN
# QHXI2               NaN           NaN
# FXI3S      2.000000e+00  4.480000e+01
# QFXI3S     0.000000e+00  9.000000e+00
# DXI3S      1.400000e+02  1.400000e+02
# QDXI3S     1.000000e+00  9.000000e+00
# HXI3S      0.000000e+00  2.359000e+03
# QHXI3S     1.000000e+00  9.000000e+00
# DRR        0.000000e+00  1.440000e+03
# QDRR       0.000000e+00  9.000000e+00

# %%
# 10. Outlier Detection (Boxplots for Numeric Features)
n_cols = 4  # Number of plots per row
valid_cols = [col for col in num_cols if df[col].dropna().nunique() > 0]  # Exclude empty columns
num_features = len(valid_cols)

n_rows = -(-num_features // n_cols)  # Ceiling division

fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 4, n_rows * 4))
axes = axes.flatten()

for i, col in enumerate(num_cols):
    sns.boxplot(y=df_numeric[col], ax=axes[i])
    axes[i].set_title(f"Boxplot of {col}")

# Hide unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

print("\nEDA Completed!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 12
#       9 axes = axes.flatten()
#      11 for i, col in enumerate(num_cols):
# ---> 12     sns.boxplot(y=df_numeric[col], ax=axes[i])
#      13     axes[i].set_title(f"Boxplot of {col}")
#      15 # Hide unused subplots
#
# File ~/.pyenv/versions/3.10.6/envs/climate_change_project/lib/python3.10/site-packages/seaborn/categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
#    1635     width=width,
#    1636     dodge=dodge,
#    1637     gap=gap,
#    1638     fill=fill,
#    1639     whis=whis,
#    1640     color=color,
#    1641     linecolor=linecolor,
#    1642     linewidth=linewidth,
#    1643     fliersize=fliersize,
#    1644     plot_kws=kwargs,
#    1645 )
#    1647 p._add_axis_labels(ax)
#    1648 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~/.pyenv/versions/3.10.6/envs/climate_change_project/lib/python3.10/site-packages/seaborn/categorical.py:700, in _CategoricalPlotter.plot_boxes(self, width, dodge, gap, fill, whis, color, linecolor, linewidth, fliersize, plot_kws)
#     679 default_kws = dict(
#     680     bxpstats=stats.to_dict("records"),
#     681     positions=data[self.orient],
#    (...)
#     697     )
#     698 )
#     699 boxplot_kws = {**default_kws, **plot_kws}
# --> 700 artists = ax.bxp(**boxplot_kws)
#     702 # Reset artist widths after adding so everything stays positive
#     703 ori_idx = ["x", "y"].index(self.orient)
#
# File ~/.pyenv/versions/3.10.6/envs/climate_change_project/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/climate_change_project/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4479, in Axes.bxp(self, bxpstats, positions, widths, vert, orientation, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder, capwidths, label)
#    4477     positions = list(range(1, N + 1))
#    4478 elif len(positions) != N:
# -> 4479     raise ValueError(datashape_message.format("positions"))
#    4481 positions = np.array(positions)
#    4482 if len(positions) > 0 and not all(isinstance(p, Real) for p in positions):
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %% [markdown]
# ## NOTES:
# 1. 58 features- Assign the names of columns from the documentation.txt
# 2. 120 Places across department 13, France
# 3. TM- daily average of hourly shelter temperatures (in °C and 1/10) as the target y?
# 4. Drop columns as no data. Same for other departments?
# FF2M,1202310
# QFF2M 1202310
# FXI2         1202310
# QFXI2        1202310
# DXI2         1202310
# QDXI2        1202310
# HXI2         1202310
# QHXI2        1202310
# 6. Code to pull all the same relevant data from all department datasets?
# 7. Run same model on all departments? Append all the data for all departments on France?

# %%
unique_values = df["NOM_USUEL"].unique()
print(unique_values)
# Out:
# ['AIX-PUYRICARD' 'AIX-LES MILLES' 'AIX EN PROVENCE' 'AIX-LA-MOLLE'
#  'ARLES-VILLE' 'ARLES-SALIN' 'ARLES' 'ARLES-SAMBUC' 'ARLES-ROUSTY'
#  'ARLES-MAS-REY' 'AUBAGNE' 'AUBAGNE-DDE' 'AURIOL COL DE LA COUTRONNE'
#  'BARBENTANE' 'BERRE' 'BOUC-BEL-AIR BOURG' 'CABRIES' 'CARRY-LE-ROUET'
#  'CASSIS-POMPIERS' 'CASSIS' 'CHARLEVAL BOURG' 'CHATEUNEUF-LES'
#  'CHATEAURENARD' 'BEC DE L AIGLE' 'LA CIOTAT LA GUILLAUMIERE'
#  'LA CIOTAT PAVILLON DU PORT' 'CUGES-LES-PINS' 'STE BAUME'
#  'LA DESTROUSSE BOURG' 'LA DESTROUSSE_SAPC' 'EYGUIERES'
#  'EYRAGUES DOMAINE DE BEAUCHAMP' 'EYRAGUES' 'LA FARE LES OLIVIERS'
#  'FOS-SUR-MER SOLMER' 'GARDANNE' 'GARDANNE LA MINE' 'GEMENOS'
#  'GRAVESON EDF' 'GREASQUE LA MINE' 'ISTRES' 'JOUQUES' 'LAMBESC'
#  'MALLEMORT-VILLE' 'MALLEMORT' 'MALLEMORT QUARTIER DES CLOS' 'MARIGNANE'
#  'MARSEILLE-OBS' 'MARSEILLE-MOUREPIANE' 'MARSEILLE-PLANIER' 'POMEGUES'
#  'MARSEILLE-ST BARNABE' 'MARSEILLE-STE MARTHE' 'MARSEILLE MONT ROSE'
#  'MARSEILLE ARENC' 'MARSEILLE-BOREL' 'MRS-PHARO' 'MRS-LA-BOUDINIE'
#  'MARSEILLE-OLIVES' 'MARSEILLE' 'MARTIGUES-COURONNE' 'CAP COURONNE'
#  'MARTIGUES PONTEAU - EDF' 'MARTIGUES' 'MEYRARGUES' 'MEYREUIL' 'MIMET'
#  'MIRAMAS PONTS ET CHAUSSEES' 'LA PENNE-SUR-HUVEAUNE ECOLE'
#  'LES PENNES-MIRABEAU' 'PEYROLLES-EN-PROVENCE EDF' 'PEYROLLES_FORET'
#  'PEYROLLES EN PROVENCE' "PLAN-D'ORGON SAINT-ESTEVE" 'PORT-DE-BOUC-SJ'
#  'PORT-DE-BOUC BOTTAI' 'PORT-DE-BOUC-TP' 'PORT-ST-LOUIS-DU-RHONE-MAS'
#  'PORT-SAINT-LOUIS-DU-RHONE-P-C' 'PORT-ST-LOUIS-DU-RHONE-GARAGE'
#  'LE-PUY-STE-REPA' 'ROGNES' 'ROGNES TOURNEFORT' 'ROQUEFORT-LA-BEDOULE'
#  'ROQUEFORT-LA-BEDOULE ECOLE' 'ROQUEVAIRE' 'ROUSSET' 'ST-ANDIOL'
#  'ST CANNAT' 'ST CHAMAS' 'STES MARIES-DDE' 'STES-MARIES-DE-LA-MER'
#  'SAINT-MARTIN-DE-CRAU VILLAGE' 'ST-MARTIN-CRAU'
#  'SAINT-MARTIN-DE-CRAU VERGIERE' 'ST-MARTIN-LE LUQUIER'
#  'SAINT-PAUL-LES-DURANCE' 'SAINT-REMY-DE-PROVENCE CANAL'
#  'ST-REMY-DE-PROVENCE' 'ST-REMY-DE-PROVENCE GRAZILLE' 'SALON DE PROVENCE'
#  'SALON-LE-MERLE' 'SENAS BOURG' 'SEPTEMES-LES-VALLONS' 'TARASCON-PC'
#  'TARASCON' 'TRETS CARREAU DE LA MINE' 'TRETS-PC' 'TRETS' 'VAUVENARGUES'
#  'VENELLES PONTS ET CHAUSSEES' 'VENELLES']

# %% [markdown]
# ## Plot the locations of the places detailed in the dataset

# %%
import folium
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# List of locations
locations = [
    'AIX-PUYRICARD', 'AIX-LES MILLES', 'AIX EN PROVENCE', 'AIX-LA-MOLLE',
    'ARLES-VILLE', 'ARLES-SALIN', 'ARLES', 'ARLES-SAMBUC', 'ARLES-ROUSTY',
    'ARLES-MAS-REY', 'AUBAGNE', 'AUBAGNE-DDE', 'AURIOL COL DE LA COUTRONNE',
    'BARBENTANE', 'BERRE', 'BOUC-BEL-AIR BOURG', 'CABRIES', 'CARRY-LE-ROUET',
    'CASSIS-POMPIERS', 'CASSIS', 'CHARLEVAL BOURG', 'CHATEUNEUF-LES',
    'CHATEAURENARD', 'BEC DE L AIGLE', 'LA CIOTAT LA GUILLAUMIERE',
    'LA CIOTAT PAVILLON DU PORT', 'CUGES-LES-PINS', 'STE BAUME',
    'LA DESTROUSSE BOURG', 'LA DESTROUSSE_SAPC', 'EYGUIERES',
    'EYRAGUES DOMAINE DE BEAUCHAMP', 'EYRAGUES', 'LA FARE LES OLIVIERS',
    'FOS-SUR-MER SOLMER', 'GARDANNE', 'GARDANNE LA MINE', 'GEMENOS',
    'GRAVESON EDF', 'GREASQUE LA MINE', 'ISTRES', 'JOUQUES', 'LAMBESC',
    'MALLEMORT-VILLE', 'MALLEMORT', 'MALLEMORT QUARTIER DES CLOS', 'MARIGNANE',
    'MARSEILLE-OBS', 'MARSEILLE-MOUREPIANE', 'MARSEILLE-PLANIER', 'POMEGUES',
    'MARSEILLE-ST BARNABE', 'MARSEILLE-STE MARTHE', 'MARSEILLE MONT ROSE',
    'MARSEILLE ARENC', 'MARSEILLE-BOREL', 'MRS-PHARO', 'MRS-LA-BOUDINIE',
    'MARSEILLE-OLIVES', 'MARSEILLE', 'MARTIGUES-COURONNE', 'CAP COURONNE',
    'MARTIGUES PONTEAU - EDF', 'MARTIGUES', 'MEYRARGUES', 'MEYREUIL', 'MIMET',
    'MIRAMAS PONTS ET CHAUSSEES', 'LA PENNE-SUR-HUVEAUNE ECOLE',
    'LES PENNES-MIRABEAU', 'PEYROLLES-EN-PROVENCE EDF', 'PEYROLLES_FORET',
    'PEYROLLES EN PROVENCE', "PLAN-D'ORGON SAINT-ESTEVE", 'PORT-DE-BOUC-SJ',
    'PORT-DE-BOUC BOTTAI', 'PORT-DE-BOUC-TP', 'PORT-ST-LOUIS-DU-RHONE-MAS',
    'PORT-SAINT-LOUIS-DU-RHONE-P-C', 'PORT-ST-LOUIS-DU-RHONE-GARAGE',
    'LE-PUY-STE-REPA', 'ROGNES', 'ROGNES TOURNEFORT', 'ROQUEFORT-LA-BEDOULE',
    'ROQUEFORT-LA-BEDOULE ECOLE', 'ROQUEVAIRE', 'ROUSSET', 'ST-ANDIOL',
    'ST CANNAT', 'ST CHAMAS', 'STES MARIES-DDE', 'STES-MARIES-DE-LA-MER',
    'SAINT-MARTIN-DE-CRAU VILLAGE', 'ST-MARTIN-CRAU',
    'SAINT-MARTIN-DE-CRAU VERGIERE', 'ST-MARTIN-LE LUQUIER',
    'SAINT-PAUL-LES-DURANCE', 'SAINT-REMY-DE-PROVENCE CANAL',
    'ST-REMY-DE-PROVENCE', 'ST-REMY-DE-PROVENCE GRAZILLE', 'SALON DE PROVENCE',
    'SALON-LE-MERLE', 'SENAS BOURG', 'SEPTEMES-LES-VALLONS', 'TARASCON-PC',
    'TARASCON', 'TRETS CARREAU DE LA MINE', 'TRETS-PC', 'TRETS', 'VAUVENARGUES',
    'VENELLES PONTS ET CHAUSSEES', 'VENELLES'
]

# Initialize geolocator
geolocator = Nominatim(user_agent="location_mapper")

# Function to get coordinates
def geocode_location(location):
    try:
        return geolocator.geocode(f"{location}, France", timeout=10)
    except GeocoderTimedOut:
        return None

# Create a map centered on France
m = folium.Map(location=[46.603354, 1.888334], zoom_start=6)

# Geocode each location and add to the map
for place in locations:
    geo = geocode_location(place)
    if geo:
        folium.Marker(
            location=[geo.latitude, geo.longitude],
            popup=place,
            icon=folium.Icon(color="blue", icon="info-sign")
        ).add_to(m)
    else:
        print(f"Geocoding failed for: {place}")

# Save the map to an HTML file
m.save("france_locations_map.html")
# Out:
# Geocoding failed for: ARLES-ROUSTY
# Geocoding failed for: AUBAGNE-DDE
# Geocoding failed for: AURIOL COL DE LA COUTRONNE
# Geocoding failed for: BOUC-BEL-AIR BOURG
# Geocoding failed for: CASSIS-POMPIERS
# Geocoding failed for: CHATEUNEUF-LES
# Geocoding failed for: LA CIOTAT LA GUILLAUMIERE
# Geocoding failed for: LA CIOTAT PAVILLON DU PORT
# Geocoding failed for: LA DESTROUSSE BOURG
# Geocoding failed for: LA DESTROUSSE_SAPC
# Geocoding failed for: EYRAGUES DOMAINE DE BEAUCHAMP
# Geocoding failed for: FOS-SUR-MER SOLMER
# Geocoding failed for: GARDANNE LA MINE
# Geocoding failed for: GRAVESON EDF
# Geocoding failed for: GREASQUE LA MINE
# Geocoding failed for: MALLEMORT-VILLE
# Geocoding failed for: MALLEMORT QUARTIER DES CLOS
# Geocoding failed for: MARSEILLE-OBS
# Geocoding failed for: MARSEILLE-PLANIER
# Geocoding failed for: MARSEILLE-BOREL
# Geocoding failed for: MRS-PHARO
# Geocoding failed for: MRS-LA-BOUDINIE
# Geocoding failed for: MARTIGUES PONTEAU - EDF
# Geocoding failed for: MIRAMAS PONTS ET CHAUSSEES
# Geocoding failed for: LA PENNE-SUR-HUVEAUNE ECOLE
# Geocoding failed for: PEYROLLES-EN-PROVENCE EDF
# Geocoding failed for: PEYROLLES_FORET
# Geocoding failed for: PLAN-D'ORGON SAINT-ESTEVE
# Geocoding failed for: PORT-DE-BOUC-SJ
# Geocoding failed for: PORT-ST-LOUIS-DU-RHONE-MAS
# Geocoding failed for: PORT-SAINT-LOUIS-DU-RHONE-P-C
# Geocoding failed for: PORT-ST-LOUIS-DU-RHONE-GARAGE
# Geocoding failed for: LE-PUY-STE-REPA
# Geocoding failed for: ROGNES TOURNEFORT
# Geocoding failed for: ROQUEFORT-LA-BEDOULE ECOLE
# Geocoding failed for: STES MARIES-DDE
# Geocoding failed for: STES-MARIES-DE-LA-MER
# Geocoding failed for: SAINT-MARTIN-DE-CRAU VILLAGE
# Geocoding failed for: SAINT-MARTIN-DE-CRAU VERGIERE
# Geocoding failed for: ST-MARTIN-LE LUQUIER
# Geocoding failed for: SAINT-REMY-DE-PROVENCE CANAL
# Geocoding failed for: ST-REMY-DE-PROVENCE GRAZILLE
# Geocoding failed for: SENAS BOURG
# Geocoding failed for: TRETS CARREAU DE LA MINE
# Geocoding failed for: VENELLES PONTS ET CHAUSSEES

# %%
# file:///Users/davidcraig/code/antoninolm/climate_change_project/raw_data/france_locations_map.html
